# %% [markdown]
# <a href="https://colab.research.google.com/github/ErosVerdejo/estadistica/blob/main/tarea2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# integrantes : geoffrey perez y eros verdejo

# %%
install.packages("ggplot2")
library(ggplot2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
#Semilla de reproducibilidad
set.seed(732173217)


muestra = 10
muestra = rnorm(muestra, mean = 82, sd = 5.35)
length(muestra) #tamaño
mean(muestra) #media
var(muestra) #varianza
sd(muestra) #desviación estándar

ggplot(data.frame(x = muestra), aes(x)) + geom_histogram(binwidth = 1.5, fill = "hotpink", color = "purple2") +labs(title = "estaturas de niños(8 años)",x = "", y = "")
# Out:
# [1] 10
# [1] 80.6095
# [1] 22.46978
# [1] 4.74023
# plot without title

# %%
set.seed(732173217)
muestra = 50
muestra = rnorm(muestra, mean = 82, sd = 5.35)
length(muestra) #tamaño
mean(muestra) #media
var(muestra) #varianza
sd(muestra) #desviación estándar
ggplot(data.frame(x = muestra), aes(x)) + geom_histogram(binwidth = 1.5, fill = "hotpink", color = "purple2") +labs(title = "estaturas de niños(8 años)",x = "", y = "")
# Out:
# [1] 50
# [1] 81.41742
# [1] 36.56063
# [1] 6.046539
# plot without title

# %%
set.seed(732173217)
muestra = 100
muestra = rnorm(muestra, mean = 82, sd = 5.35)
length(muestra) #tamaño
mean(muestra) #media
var(muestra) #varianza
sd(muestra) #desviación estándar
ggplot(data.frame(x = muestra), aes(x)) + geom_histogram(binwidth = 1.5, fill = "hotpink", color = "purple2") +labs(title = "estaturas de niños(8 años)",x = "", y = "")
# Out:
# [1] 100
# [1] 81.52423
# [1] 31.31845
# [1] 5.596289
# plot without title

# %%
set.seed(732173217)
muestra = 1000
muestra = rnorm(muestra, mean = 82, sd = 5.35)
length(muestra) #tamaño
mean(muestra) #media
var(muestra) #varianza
sd(muestra) #desviación estándar
ggplot(data.frame(x = muestra), aes(x)) + geom_histogram(binwidth = 1.5, fill = "hotpink", color = "purple2") +labs(title = "estaturas de niños(8 años)",x = "", y = "")
# Out:
# [1] 1000
# [1] 81.83037
# [1] 29.78201
# [1] 5.45729
# plot without title

# %% [markdown]
# **Item I "Estaturas en nuestra comuna" normal**
#
# 2.- la relación que se muestra es que mientras mas grande la muestra más similar o se aproxima más a los valores dados por el ejercicio (media y desviación estánda).
#
# 3.- esto significa que carlitos esta por encima de la media y que es mas alto que el 90% de los niños de 8 años. Para resumir es una forma de comparar la estatura de carlitos con otros niños.

# %%
#Semilla de reproducibilidad
set.seed(234576465)

n_lanzamientos = 20
p_cara = 0.5

# Item II "Lanzamiento de una moneda"
# inciso 1.
resultado_1 = rbinom(1, size = n_lanzamientos, prob = p_cara)
cat("Cantidad de caras para 20 lanzamientos:", resultado_1, "\n")

# inciso 2.
simulacion_1 = rbinom(5, size = 20, prob = p_cara)
ggplot(data.frame(x = simulacion_1), aes(x)) + geom_histogram(binwidth = 1.5, fill = "orange", color = "yellow") +labs(title = "Histograma para 5 experimentos",x = "", y = "")
# Out:
# Cantidad de caras para 20 lanzamientos: 11
# plot without title

# %%
# Item II "Lanzamiento de una moneda" inciso 2.
set.seed(777696665)
simulacion_1 = rbinom(50, size = 20, prob = p_cara)
ggplot(data.frame(x = simulacion_1), aes(x)) + geom_histogram(binwidth = 1.5, fill = "orange", color = "yellow") +labs(title = "Histograma para 50 experimentos",x = "", y = "")
# Out:
# plot without title

# %%
# Item II "Lanzamiento de una moneda" inciso 2.
set.seed(777696664)
simulacion_1 = rbinom(100, size = 20, prob = p_cara)
ggplot(data.frame(x = simulacion_1), aes(x)) + geom_histogram(binwidth = 1.5, fill = "orange", color = "yellow") +labs(title = "Histograma para 100 experimentos",x = "", y = "")
# Out:
# plot without title

# %%
# Item II "Lanzamiento de una moneda" inciso 2.
set.seed(777696663)
simulacion_1 = rbinom(1000, size = 20, prob = p_cara)
ggplot(data.frame(x = simulacion_1), aes(x)) + geom_histogram(binwidth = 1.5, fill = "orange", color = "yellow") +labs(title = "Histograma para 1000 experimentos",x = "", y = "")
# Out:
# plot without title

# %%
# Item II "Lanzamiento de una moneda" inciso 3.
set.seed(777696662)
simulacion_1 = rbinom(1000, size = 100, prob = p_cara)
ggplot(data.frame(x = simulacion_1), aes(x)) + geom_histogram(binwidth = 1.5, fill = "orange", color = "yellow") +labs(title = "Histograma para 1000 experimentos de 100 datos cada uno",x = "", y = "")
# Out:
# plot without title

# %%
# Item II "Lanzamiento de una moneda" inciso 4.
probAc_50 = pbinom(50, size = 100, prob = 0.3)
cat("La probabilidad de obtener 50 caras o menos en 100 lanzamientos es P(X <= 50) =", probAc_50, "\n")
# Out:
# La probabilidad de obtener 50 caras o menos en 100 lanzamientos es P(X <= 50) = 0.999991

# %%
# Item II "Lanzamiento de una moneda" inciso 5.
set.seed(777696662)
simulacion_1 = rbinom(1000, size = 100, prob = p_cara)
media = 100 * 0.5
ds = sqrt(100 * 0.5 * 0.5)
ggplot(data.frame(x = simulacion_1), aes(x)) + stat_function(fun = dnorm, args = list(mean = media, sd = ds), color = "red", linewidth = 2) + geom_histogram(aes(y = ..density..), binwidth = 1.5, fill = "orange", color = "yellow")
# Out:
# plot without title

# %%
# Item II "Lanzamiento de una moneda" inciso 6.
media = 100 * 0.5
ds = sqrt(100 * 0.5 * 0.5)
valor_corregido = 50.5
probNormal_corregida = pnorm(valor_corregido, mean = media, sd = ds)

cat("La probabilidad aproximada usando la Normal con corrección de continuidad es P(X <= 50.5) =", probNormal_corregida, "\n")

probBinomial_exacta = pbinom(q = 50, size = 100, prob = 0.5)
cat("--- Comparación de Resultados ---\n")
cat("Valor exacto (Binomial):", probBinomial_exacta, "\n")
cat("Valor aproximado (Normal con corrección):", probNormal_corregida, "\n")
cat("Diferencia:", probNormal_corregida - probBinomial_exacta, "\n\n")
cat("Al restamos tenemos que la diferencia es de 0.00000000502 lo cual nos demuestra que estos dos metodos nos entregan una precision muy fina en los resultados\n")
cat("pero aún asi el que entrega el valor mas preciso es la binomial\n")
# Out:
# La probabilidad aproximada usando la Normal con corrección de continuidad es P(X <= 50.5) = 0.5398278
# --- Comparación de Resultados ---
# Valor exacto (Binomial): 0.5397946
# Valor aproximado (Normal con corrección): 0.5398278
# Diferencia: 3.321858e-05
#
# Al restamos tenemos que la diferencia es de 0.00000000502 lo cual nos demuestra que estos dos metodos nos entregan una precision muy fina en los resultados
# pero aún asi el que entrega el valor mas preciso es la binomial

# %%
#**Item III "Llamadas por horas en Callcenter" poisson**
set.seed(732173217)
muestra= 1000
muestra= rpois(muestra, lambda = 15)
length(muestra) #tamaño
mean(muestra) #media
var(muestra) #varianza
sd(muestra) #desviación estándar

ggplot(data.frame(x = muestra), aes(x)) + geom_histogram(binwidth = 1.5, fill = "hotpink", color = "purple2") +labs(title = "Gráfico de Frecuencias",x = "", y = "")
# Out:
# [1] 1000
# [1] 14.87
# [1] 14.08318
# [1] 3.752757
# plot without title

# %%
set.seed(732173217)
ppois(16, 15, lower.tail = FALSE)
1 - pnorm((16.5 -15)/sqrt(15))
# Out:
# [1] 0.3358768
# [1] 0.3492677

# %% [markdown]
# **Item III "Llamadas por horas en Callcenter" poisson**
#
# 2.1- según investigamos para poder hacer eso se requiere tener un lambda grande según algunas referencias daban un rango de lambda mayor a 10. Es importante aplicar la corrección por continuidad, ya que la Poisson es discreta y la Normal es continua.
#
# 2.2- para P(X ≥ 17) nos dio por poisson 0.335... y por normal 0.349... con eso concluimos que pon normal se acerca pero en este caso sobreestima la probabilidad y la probabilidad por poisson es mas eficaz en este ejercicio.

# %%
set.seed(732173217)
muestra= 1000
muestra= rpois(muestra, lambda = 15)
ggplot(data.frame(x = muestra), aes(x)) + geom_histogram(binwidth = 1.5, fill = "hotpink", color = "purple2") +labs(title = "Llamadas por hora en Callcenter",x = "", y = "")
# Out:
# plot without title

# %%
set.seed(732173217)
muestra= 1000
muestra= rnorm(1000, mean = 15, sd = 3.873)
ggplot(data.frame(x = muestra), aes(x)) + geom_histogram(binwidth = 1.5, fill = "hotpink", color = "purple2") +labs(title = "Llamadas por hora en Callcenter",x = "", y = "")
# Out:
# plot without title

# %% [markdown]
# **distribución geometrica**
#
# 1.- Una variable aleatoria geométrica cuenta el número de intentos (ensayos) hasta obtener el primer éxito en una secuencia de pruebas independientes, donde cada prueba tiene la misma probabilidad de éxito, representada por 'p'. La variable puede tomar valores enteros desde 1 en adelante (1, 2, 3, ...).
# Parametro:
# 𝑋
# ∼
# Geom
# (
# 𝑝
# )
# X∼Geom(p)
#
# 𝑝 ∈ ( 0,1)
# : probabilidad de éxito en cada ensayo.
#
#
# 2.- ejemplo: lanzamos una moneda cargada, donde la probabilidad que salga cara es de 0.6
#
# la variable X∼Geom(p=0.6) representa la cantidad de veces que se necesita lanzar una moneda para que salga cara.
# la distribución geometrica se usa para fenomenos como :
#
# . numero de veces hasta que un proceso falla o es exitoso.
#
# . numero de personas hasta que alguno compre.
#
# . investigación de mercado, prueba de productos.
#
# . investigación de enfermedades.

# %%
#Item IV "Distribución geometrica" inciso 3.
set.seed(732173217)
p1 = 0.6
simulacion_p1 = rgeom(n = 100, prob = p1)

ggplot(data.frame(x = simulacion_p1), aes(x)) + geom_histogram(binwidth = 1.5, fill = "seagreen3", color = "black") +labs(title = "Histograma para 100 valores, parametro = 0.6",x = "", y = "")
# Out:
# plot without title

# %%
#Item IV "Distribución geometrica" inciso 3.
set.seed(732173218)
p1 = 0.4
simulacion_p1 = rgeom(n = 100, prob = p1)

ggplot(data.frame(x = simulacion_p1), aes(x)) + geom_histogram(binwidth = 1.5, fill = "seagreen3", color = "black") +labs(title = "Histograma para 100 valores, parametro = 0.4",x = "", y = "")
# Out:
# plot without title

# %%
#Item IV "Distribución geometrica" inciso 3.
set.seed(732173219)
p1 = 0.1
simulacion_p1 = rgeom(n = 100, prob = p1)

ggplot(data.frame(x = simulacion_p1), aes(x)) + geom_histogram(binwidth = 1.5, fill = "seagreen3", color = "black") +labs(title = "Histograma para 100 valores, parametro = 0.1",x = "", y = "")
# Out:
# plot without title

# %%
#Item IV "Distribución geometrica" inciso 3.
set.seed(732173220)
p1 = 0.01
simulacion_p1 = rgeom(n = 100, prob = p1)

ggplot(data.frame(x = simulacion_p1), aes(x)) + geom_histogram(binwidth = 1.5, fill = "seagreen3") +labs(title = "Histograma para 100 valores, parametro = 0.01",x = "", y = "")
# Out:
# plot without title

# %% [markdown]
# **Item IV "Distribución geometrica" inciso 3.**
#
# Como logramos apreciar en las graficas anteriores, a medida de que el parametro usado en la distribucion geometrica baja, implica que las colas de esperas para que suceda un exito son mas largas, esto a su vez, demuestra que a un menor valor del parametro significa una mayor probabilidad de fracaso en cada intento
